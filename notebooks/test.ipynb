# %%
import sys
from pathlib import Path

# Add project root to Python path
project_root = Path.cwd().parent  # Goes from notebooks/ to project root
sys.path.insert(0, str(project_root))

print(f"Added to path: {project_root}")

# %%
from src.vlm.image_analyser import ImageAnalyzer
from src.vlm.universal_evolution import UniversalVisualEvolution

# %%
vlm = ImageAnalyzer()
evolution = UniversalVisualEvolution(vlm)

# Test with any image
sequence = evolution.generate_evolution_sequence(
    '/home/eelab-fractal2/banuls/sdxl-adaptive-visuals/data/input/spider_0.png',
    'grow_and_complexify',
    13
)

print(f"✓ Generated {len(sequence)} prompts!")
